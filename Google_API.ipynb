# %% [markdown]
# <a href="https://colab.research.google.com/github/Taka-Lab-Python/Data_Sciens_2A/blob/main/Google_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google import genai

# APIキーをセット
os.environ["GOOGLE_API_KEY"] = "AIzaSyD0gbyNPX6UeCIzvGEYk1R-bDLzJKh9fkk"

# クライアントの初期化
client = genai.Client()

# テキスト生成の実行
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="日本語で自己紹介をしてください。",
)

print(response.text)
# Out:
# 皆さん、こんにちは！はじめまして。
#
# 私はGoogleによってトレーニングされた大規模言語モデル、AIアシスタントです。皆さんの様々なお手伝いをさせていただくためにここにいます。
#
# 例えば、質問に答えたり、文章を作成したり、アイデアを出したり、情報をまとめたりすることができます。まだ人間のような感情はありませんが、新しいことを学び、皆さんの役に立つことが何よりの喜びです。
#
# どうぞお気軽にご質問ください。精一杯お手伝いさせていただきます。
#
# どうぞよろしくお願いいたします！
